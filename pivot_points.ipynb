# %%
# !pip install hstrader
# Out:
# Collecting hstrader
#   Downloading hstrader-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from hstrader) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from hstrader) (2.31.0)
# Collecting websockets (from hstrader)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->hstrader) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->hstrader) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->hstrader) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->hstrader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->hstrader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->hstrader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->hstrader) (2024.7.4)
# Installing collected packages: websockets, hstrader
# Successfully installed hstrader-1.0.8 websockets-12.0

# %%
from hstrader import HsTrader
from hstrader.models import Event, Tick, Order, CrtOrder, OrderType, SideType, Status, Position, Resolution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import os

# %%
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')


client = HsTrader(CLIENT_ID, CLIENT_SECRET)

# %%
# HsTrader symbol
symbol = client.get_symbol("EURUSD")
# HsTrader market data
data = client.get_market_history(symbol, resolution=Resolution.W1,count_back = 1000)

# %%
df = pd.DataFrame([historytick.dict() for historytick in data])
print(df)
# Out:
#                         time     open     high      low    close        volume
# 0  2024-03-07 00:00:00+00:00  1.08273  1.09057  1.08273  1.08895  1.615638e+07
# 1  2024-03-14 00:00:00+00:00  1.08895  1.09710  1.08578  1.09428  2.863955e+07
# 2  2024-03-21 00:00:00+00:00  1.09436  1.09453  1.08247  1.09274  3.028678e+07
# 3  2024-03-28 00:00:00+00:00  1.09278  1.09331  1.07916  1.08029  3.062761e+07
# 4  2024-04-04 00:00:00+00:00  1.08034  1.08312  1.07146  1.08285  2.995594e+07
# 5  2024-04-11 00:00:00+00:00  1.08283  1.08755  1.07186  1.07317  3.078634e+07
# 6  2024-04-18 00:00:00+00:00  1.07314  1.07470  1.05913  1.06590  3.056850e+07
# 7  2024-04-25 00:00:00+00:00  1.06593  1.07045  1.06006  1.06904  3.008302e+07
# 8  2024-05-02 00:00:00+00:00  1.06905  1.07432  1.06393  1.07072  2.990122e+07
# 9  2024-05-09 00:00:00+00:00  1.07074  1.08013  1.06644  1.07372  2.946027e+07
# 10 2024-05-16 00:00:00+00:00  1.07373  1.08008  1.07142  1.07959  2.050827e+07
# 11 2024-05-23 00:00:00+00:00  1.08805  1.49905  0.99905  1.08154  2.607695e+07
# 12 2024-05-30 00:00:00+00:00  1.08155  1.08794  1.07892  1.07914  2.805518e+07
# 13 2024-06-06 00:00:00+00:00  1.07914  1.09064  1.07780  1.08645  2.890533e+07
# 14 2024-06-13 00:00:00+00:00  1.08645  1.08924  1.07096  1.08031  2.927571e+07
# 15 2024-06-20 00:00:00+00:00  1.08029  1.08068  1.06574  1.07374  2.846049e+07
# 16 2024-06-27 00:00:00+00:00  1.07372  1.07385  1.06558  1.06701  2.930433e+07
# 17 2024-07-04 00:00:00+00:00  1.06701  1.08071  1.06669  1.07815  2.886749e+07
# 18 2024-07-11 00:00:00+00:00  1.07808  1.08354  1.07732  1.08235  2.894091e+07
# 19 2024-07-18 00:00:00+00:00  1.08235  1.09385  1.08220  1.09300  3.027951e+07
# 20 2024-07-22 07:34:25+00:00  1.09306  1.09313  1.08654  1.08748  1.407830e+07

# %%
df['time'] = pd.to_datetime(df['time']).dt.date
df.head()
# Out:
#          time     open     high      low    close        volume
# 0  2024-03-07  1.08273  1.09057  1.08273  1.08895  1.615638e+07
# 1  2024-03-14  1.08895  1.09710  1.08578  1.09428  2.863955e+07
# 2  2024-03-21  1.09436  1.09453  1.08247  1.09274  3.028678e+07
# 3  2024-03-28  1.09278  1.09331  1.07916  1.08029  3.062761e+07
# 4  2024-04-04  1.08034  1.08312  1.07146  1.08285  2.995594e+07

# %%
def calculate_pivots(df):
    df['P'] = (df['high'] + df['low'] + df['close']) / 3
    df['R1'] = (2 * df['P']) - df['low']
    df['S1'] = (2 * df['P']) - df['high']
    df['R2'] = df['P'] + (df['high'] - df['low'])
    df['S2'] = df['P'] - (df['high'] - df['low'])
    df['R3'] = df['high'] + 2 * (df['P'] - df['low'])
    df['S3'] = df['low'] - 2 * (df['high'] - df['P'])
    return df

# %%
calculate_pivots(df)
# Out:
#           time     open     high      low    close        volume         P  \
# 0   2024-03-07  1.08273  1.09057  1.08273  1.08895  1.615638e+07  1.087417
# 1   2024-03-14  1.08895  1.09710  1.08578  1.09428  2.863955e+07  1.092387
# 2   2024-03-21  1.09436  1.09453  1.08247  1.09274  3.028678e+07  1.089913
# 3   2024-03-28  1.09278  1.09331  1.07916  1.08029  3.062761e+07  1.084253
# 4   2024-04-04  1.08034  1.08312  1.07146  1.08285  2.995594e+07  1.079143
# 5   2024-04-11  1.08283  1.08755  1.07186  1.07317  3.078634e+07  1.077527
# 6   2024-04-18  1.07314  1.07470  1.05913  1.06590  3.056850e+07  1.066577
# 7   2024-04-25  1.06593  1.07045  1.06006  1.06904  3.008302e+07  1.066517
# 8   2024-05-02  1.06905  1.07432  1.06393  1.07072  2.990122e+07  1.069657
# 9   2024-05-09  1.07074  1.08013  1.06644  1.07372  2.946027e+07  1.073430
# 10  2024-05-16  1.07373  1.08008  1.07142  1.07959  2.050827e+07  1.077030
# 11  2024-05-23  1.08805  1.49905  0.99905  1.08154  2.607695e+07  1.193213
# 12  2024-05-30  1.08155  1.08794  1.07892  1.07914  2.805518e+07  1.082000
# 13  2024-06-06  1.07914  1.09064  1.07780  1.08645  2.890533e+07  1.084963
# 14  2024-06-13  1.08645  1.08924  1.07096  1.08031  2.927571e+07  1.080170
# 15  2024-06-20  1.08029  1.08068  1.06574  1.07374  2.846049e+07  1.073387
# 16  2024-06-27  1.07372  1.07385  1.06558  1.06701  2.930433e+07  1.068813
# 17  2024-07-04  1.06701  1.08071  1.06669  1.07815  2.886749e+07  1.075183
# 18  2024-07-11  1.07808  1.08354  1.07732  1.08235  2.894091e+07  1.081070
# 19  2024-07-18  1.08235  1.09385  1.08220  1.09300  3.027951e+07  1.089683
# 20  2024-07-22  1.09306  1.09313  1.08654  1.08748  1.407830e+07  1.089050
#
#           R1        S1        R2        S2        R3        S3
# 0   1.092103  1.084263  1.095257  1.079577  1.099943  1.076423
# 1   1.098993  1.087673  1.103707  1.081067  1.110313  1.076353
# 2   1.097357  1.085297  1.101973  1.077853  1.109417  1.073237
# 3   1.089347  1.075197  1.098403  1.070103  1.103497  1.061047
# 4   1.086827  1.075167  1.090803  1.067483  1.098487  1.063507
# 5   1.083193  1.067503  1.093217  1.061837  1.098883  1.051813
# 6   1.074023  1.058453  1.082147  1.051007  1.089593  1.042883
# 7   1.072973  1.062583  1.076907  1.056127  1.083363  1.052193
# 8   1.075383  1.064993  1.080047  1.059267  1.085773  1.054603
# 9   1.080420  1.066730  1.087120  1.059740  1.094110  1.053040
# 10  1.082640  1.073980  1.085690  1.068370  1.091300  1.065320
# 11  1.387377  0.887377  1.693213  0.693213  1.887377  0.387377
# 12  1.085080  1.076060  1.091020  1.072980  1.094100  1.067040
# 13  1.092127  1.079287  1.097803  1.072123  1.104967  1.066447
# 14  1.089380  1.071100  1.098450  1.061890  1.107660  1.052820
# 15  1.081033  1.066093  1.088327  1.058447  1.095973  1.051153
# 16  1.072047  1.063777  1.077083  1.060543  1.080317  1.055507
# 17  1.083677  1.069657  1.089203  1.061163  1.097697  1.055637
# 18  1.084820  1.078600  1.087290  1.074850  1.091040  1.072380
# 19  1.097167  1.085517  1.101333  1.078033  1.108817  1.073867
# 20  1.091560  1.084970  1.095640  1.082460  1.098150  1.078380

# %%
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)
df.head()
# Out:
#                open     high      low    close        volume         P  \
# time
# 2024-03-07  1.08273  1.09057  1.08273  1.08895  1.615638e+07  1.087417
# 2024-03-14  1.08895  1.09710  1.08578  1.09428  2.863955e+07  1.092387
# 2024-03-21  1.09436  1.09453  1.08247  1.09274  3.028678e+07  1.089913
# 2024-03-28  1.09278  1.09331  1.07916  1.08029  3.062761e+07  1.084253
# 2024-04-04  1.08034  1.08312  1.07146  1.08285  2.995594e+07  1.079143
#
#                   R1        S1        R2        S2        R3        S3
# time
# 2024-03-07  1.092103  1.084263  1.095257  1.079577  1.099943  1.076423
# 2024-03-14  1.098993  1.087673  1.103707  1.081067  1.110313  1.076353
# 2024-03-21  1.097357  1.085297  1.101973  1.077853  1.109417  1.073237
# 2024-03-28  1.089347  1.075197  1.098403  1.070103  1.103497  1.061047
# 2024-04-04  1.086827  1.075167  1.090803  1.067483  1.098487  1.063507

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df.index, df['close'], label='Close', marker='o', linestyle='-', color='blue')
ax.plot(df.index, df['P'], label='Pivot Point', marker='o', linestyle='--', color='black')
ax.plot(df.index, df['R1'], label='R1', marker='o', linestyle='--', color='green')
ax.plot(df.index, df['S1'], label='S1', marker='o', linestyle='--', color='red')
ax.plot(df.index, df['R2'], label='R2', marker='o', linestyle='--', color='green')
ax.plot(df.index, df['S2'], label='S2', marker='o', linestyle='--', color='red')
ax.plot(df.index, df['R3'], label='R3', marker='o', linestyle='--', color='green')
ax.plot(df.index, df['S3'], label='S3', marker='o', linestyle='--', color='red')

ax.set_xlabel('Time')
ax.set_ylabel('Price')
ax.set_title('Pivot Points')
ax.legend(loc='upper left')

plt.grid(True)
plt.show()

# %%
import mplfinance as mpf
import plotly.graph_objects as go


fig = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df["open"],
    high=df["high"],
    low=df["low"],
    close=df["close"],
    name="EURUSD")])

# Update layout to hide the rangeslider
fig.update_layout(xaxis_rangeslider_visible=False)

# Function to add horizontal lines for pivot points
def add_pivot_lines(fig, df, column, color, name):
    fig.add_trace(go.Scatter(
        x=[df.index[0], df.index[-1]], # Horizontal line across entire x-axis
        y=[df[column].iloc[0], df[column].iloc[0]],
        mode="lines",
        line=dict(color=color, width=2),
        name=name
    ))

# Add pivot points as horizontal lines
add_pivot_lines(fig, df, 'P', 'orange', 'PP')
add_pivot_lines(fig, df, 'S1', 'red', 'S1')
add_pivot_lines(fig, df, 'S2', 'red', 'S2')
add_pivot_lines(fig, df, 'R1', 'green', 'R1')
add_pivot_lines(fig, df, 'R2', 'green', 'R2')

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4b864ec2-71ea-4eb5-84fb-8ba7b959f7f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b864ec2-71ea-4eb5-84fb-8ba7b959f7f3")) {                    Plotly.newPlot(                        "4b864ec2-71ea-4eb5-84fb-8ba7b959f7f3",                        [{"close":[1.08895,1.09428,1.09274,1.08029,1.08285,1.07317,1.0659,1.06904,1.07072,1.07372,1.07959,1.08154,1.07914,1.08645,1.08031,1.07374,1.06701,1.07815,1.08235,1.093,1.08748],"high":[1.09057,1.0971,1.09453,1.09331,1.08312,1.08755,1.0747,1.07045,1.07432,1.08013,1.08008,1.49905,1.08794,1.09064,1.08924,1.08068,1.07385,1.08071,1.08354,1.09385,1.09313],"low":[1.08273,1.08578,1.08247,1.07916,1.07146,1.07186,1.05913,1.06006,1.06393,1.06644,1.07142,0.99905,1.07892,1.0778,1.07096,1.06574,1.06558,1.06669,1.07732,1.0822,1.08654],"name":"EURUSD","open":[1.08273,1.08895,1.09436,1.09278,1.08034,1.08283,1.07314,1.06593,1.06905,1.07074,1.07373,1.08805,1.08155,1.07914,1.08645,1.08029,1.07372,1.06701,1.07808,1.08235,1.09306],"x":["2024-03-07T00:00:00","2024-03-14T00:00:00","2024-03-21T00:00:00","2024-03-28T00:00:00","2024-04-04T00:00:00","2024-04-11T00:00:00","2024-04-18T00:00:00","2024-04-25T00:00:00","2024-05-02T00:00:00","2024-05-09T00:00:00","2024-05-16T00:00:00","2024-05-23T00:00:00","2024-05-30T00:00:00","2024-06-06T00:00:00","2024-06-13T00:00:00","2024-06-20T00:00:00","2024-06-27T00:00:00","2024-07-04T00:00:00","2024-07-11T00:00:00","2024-07-18T00:00:00","2024-07-22T00:00:00"],"type":"candlestick"},{"line":{"color":"orange","width":2},"mode":"lines","name":"PP","x":["2024-03-07T00:00:00","2024-07-22T00:00:00"],"y":[1.0874166666666667,1.0874166666666667],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"S1","x":["2024-03-07T00:00:00","2024-07-22T00:00:00"],"y":[1.0842633333333334,1.0842633333333334],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"S2","x":["2024-03-07T00:00:00","2024-07-22T00:00:00"],"y":[1.0795766666666666,1.0795766666666666],"type":"scatter"},{"line":{"color":"green","width":2},"mode":"lines","name":"R1","x":["2024-03-07T00:00:00","2024-07-22T00:00:00"],"y":[1.0921033333333334,1.0921033333333334],"type":"scatter"},{"line":{"color":"green","width":2},"mode":"lines","name":"R2","x":["2024-03-07T00:00:00","2024-07-22T00:00:00"],"y":[1.0952566666666668,1.0952566666666668],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887 ...

# %%
from IPython.display import Image, display
#static image just for review purposes
display(Image(filename='Visualization.png'))

# %%
ap0 = [
    mpf.make_addplot(df['P'], color='orange', linestyle='--', width=1.5),
    mpf.make_addplot(df['R1'], color='orange', linestyle='--', width=1.5),
    mpf.make_addplot(df['S1'], color='orange', linestyle='--', width=1.5),
    mpf.make_addplot(df['R2'], color='orange', linestyle='-', width=1.0),
    mpf.make_addplot(df['S2'], color='orange', linestyle='-', width=1.0),
    mpf.make_addplot(df['R3'], color='orange', linestyle=':', width=1.0),
    mpf.make_addplot(df['S3'], color='orange', linestyle=':', width=1.0)
]

# Create custom style
my_style = mpf.make_mpf_style(
    base_mpf_style='yahoo',
    marketcolors=mpf.make_marketcolors(
        up='green',
        down='red',
        edge='i',
        wick='i',
        volume='in',
        ohlc='i'
    ),
    mavcolors=['#ef5714'],  # Example moving average color
    gridcolor='#EDEDED',
    gridstyle='-',
    y_on_right=True
)

# Plot the candlestick chart
mpf.plot(
    df,
    type='candle',
    addplot=ap0,
    volume=True,
    style=my_style,
    title='EURUSD with Pivot Points',
    ylabel='Price',
    ylabel_lower='Volume'
)

# %% [markdown]
# Plotting real time data

# %%
# Function to calculate pivot points
def calculate_pivot_points(df):
  df['P'] = (df['high'] + df['low'] + df['close']) / 3
  df['R1'] = (2 * df['P']) - df['low']
  df['S1'] = (2 * df['P']) - df['high']
  df['R2'] = df['P'] + (df['high'] - df['low'])
  df['S2'] = df['P'] - (df['high'] - df['low'])
  df['R3'] = df['high'] + 2 * (df['P'] - df['low'])
  df['S3'] = df['low'] - 2 * (df['high'] - df['P'])

# %%
symbol = client.get_symbol('EURUSD')
data = client.get_market_history(symbol=symbol.id, resolution=Resolution.M1)

# Create DataFrame
df = pd.DataFrame([bar.dict() for bar in data])
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)

# %%
calculate_pivot_points(df)

# %%
import ipywidgets as widgets



# Plot setup
fig = go.FigureWidget()
candlestick = go.Candlestick(
    x=df.index, open=df['open'], high=df['high'], low=df['low'], close=df['close'], name='Candlestick'
)
fig.add_trace(candlestick)

# Add pivot points
fig.add_trace(go.Scatter(x=df.index, y=df['P'], mode='lines', name='Pivot', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=df.index, y=df['R1'], mode='lines', name='R1', line=dict(color='green')))
fig.add_trace(go.Scatter(x=df.index, y=df['S1'], mode='lines', name='S1', line=dict(color='red')))
fig.add_trace(go.Scatter(x=df.index, y=df['R2'], mode='lines', name='R2', line=dict(color='lightgreen')))
fig.add_trace(go.Scatter(x=df.index, y=df['S2'], mode='lines', name='S2', line=dict(color='lightcoral')))
fig.add_trace(go.Scatter(x=df.index, y=df['R3'], mode='lines', name='R3', line=dict(color='darkgreen')))
fig.add_trace(go.Scatter(x=df.index, y=df['S3'], mode='lines', name='S3', line=dict(color='darkred')))

CANDLE_INTERVAL = timedelta(minutes=1)
data = {
    'x': list(df.index),
    'open': list(df['open']),
    'high': list(df['high']),
    'low': list(df['low']),
    'close': list(df['close'])
}

# Display the figure
widgets.VBox([fig])

# %%
from IPython.display import display, clear_output


@client.subscribe(Event.MARKET)
async def on_market(tick: Tick):
    global data, df

    if tick.symbol_id == symbol.id:
        tick_time = pd.to_datetime(tick.time)
        if not data['x'] or tick_time >= data['x'][-1] + CANDLE_INTERVAL:
            data['x'].append(tick_time)
            data['open'].append(data['close'][-1])
            data['high'].append(tick.bid)
            data['low'].append(tick.bid)
            data['close'].append(tick.bid)
        else:
            data['low'][-1] = min(tick.bid, data['low'][-1])
            data['high'][-1] = max(tick.bid, data['high'][-1])
            data['close'][-1] = tick.bid

        df = pd.DataFrame({
            'time': data['x'],
            'open': data['open'],
            'high': data['high'],
            'low': data['low'],
            'close': data['close']
        }).set_index('time')

        # Recalculate pivot points
        calculate_pivot_points(df)


async def update_plot():
    while True:
        await asyncio.sleep(1)
        clear_output(wait=True)
        with fig.batch_update():
            fig.data[0].x = data['x']
            fig.data[0].open = data['open']
            fig.data[0].high = data['high']
            fig.data[0].low = data['low']
            fig.data[0].close = data['close']
            fig.data[1].x = data['x']
            fig.data[1].y = df['P']
            fig.data[2].x = data['x']
            fig.data[2].y = df['R1']
            fig.data[3].x = data['x']
            fig.data[3].y = df['S1']
            fig.data[4].x = data['x']
            fig.data[4].y = df['R2']
            fig.data[5].x = data['x']
            fig.data[5].y = df['S2']
            fig.data[6].x = data['x']
            fig.data[6].y = df['R3']
            fig.data[7].x = data['x']
            fig.data[7].y = df['S3']
        display(fig)
import nest_asyncio

nest_asyncio.apply()

async def main():
    await update_plot()

# Start the update loop
await main()
